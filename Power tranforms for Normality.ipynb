# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#       BMI
# 0  102.40
# 1   39.46
# 2   33.72
# 3   32.37
# 4   37.61

# %%
df.hist(figsize=(15,15))  ## even if you give original df also , hist will any way plot for numeric only.
plt.show()

# %%
df['BMI_boxcox'], param = stats.boxcox(df['BMI']) 
print('Optimal λ: ', param)
# Out:
# Optimal λ:  0.03318675740139272

# %%
df
# Out:
#        BMI  BMI_boxcox
# 0   102.40    5.003353
# 1    39.46    3.908824
# 2    33.72    3.731698
# 3    32.37    3.685810
# 4    37.61    3.854621
# ..     ...         ...
# 95   60.22    4.389742
# 96   71.20    4.582164
# 97   44.45    4.043615
# 98   57.53    4.337426
# 99   70.24    4.566529
#
# [100 rows x 2 columns]

# %%
df.hist(figsize=(15,15))
plt.show()
